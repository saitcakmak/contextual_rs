# %% [markdown]
# In this notebook, we will plot the results of the experiments comparing the alternative
# acquisition functions on LCEGP.
#
# Select the key to plot below. Options are `reporting_pcs` and `final_values`.

# %%
import json
import os

import torch
from torch import Tensor

# %matplotlib inline
import matplotlib.pyplot as plt

# current_dir = os.path.dirname(os.path.abspath(__file__))
current_dir = os.getcwd()

labels = ["KG", "TS", "PCS"]
label_count = len(labels)

# TODO: may want to add a key argument here.
def plot_experiment(dirname: str, plot_idcs: list = None) -> Tensor:
    exp_dir = os.path.join(current_dir, dirname)
    config_path = os.path.join(exp_dir, "config.json")

    with open(config_path, "r") as f:
        config_dict = json.load(f)
        print(f"Config: \n {json.dumps(config_dict, indent=4)}")

    # get all the output files
    directory_list = os.listdir(exp_dir)
    output_files = [
        os.path.join(exp_dir, file) for file in directory_list if file[-3:] == ".pt"
    ]

    # read all outputs into a list
    output_dicts = list()
    for file_path in output_files:
        output_dicts.append(torch.load(file_path))
    output_count = len(output_dicts)
    print(f"Read {output_count} output files.")

    # plot final values, averaged over replications.
    # final values is a list of tensors, one tensor per label
    final_value_shape = output_dicts[0][key][0].shape
    all_results = torch.zeros(label_count, output_count, *final_value_shape)

    for j, out_dict in enumerate(output_dicts):
        for i in range(label_count):
            all_results[i, j] = out_dict[key][i].cpu()

    # average to get the plot values
    plot_values = all_results.mean(dim=1)

    # plot
    fig = plt.figure(figsize=(12, 8))
    fig.patch.set_facecolor('xkcd:mint green')
    if plot_idcs is None:
        plot_idcs = list(range(label_count))

    for i in plot_idcs:
        plt.plot(plot_values[i], label=labels[i])
    plt.grid()
    plt.legend()
    plt.show()
    return all_results


key = "final_values"

# %%
_ = plot_experiment("config_1")
# Out:
# Config:
#  {
#     "num_alternatives": 5,
#     "rho": 0.5,
#     "num_full_train": 3,
#     "iterations": 200,
#     "fit_frequency": 5,
#     "fit_tries": 1
# }
# Read 50 output files.

# %%
_ = plot_experiment("config_2")
# Out:
# Config:
#  {
#     "num_alternatives": 10,
#     "rho": 0.3,
#     "num_full_train": 3,
#     "iterations": 200,
#     "fit_frequency": 5,
#     "fit_tries": 1
# }
# Read 50 output files.

# %%
_ = plot_experiment("config_3")
# Out:
# Config:
#  {
#     "num_alternatives": 20,
#     "rho": 0.7,
#     "num_full_train": 5,
#     "iterations": 100,
#     "fit_frequency": 5,
#     "fit_tries": 1
# }
# Read 49 output files.

# %%
_ = plot_experiment("config_4")
# Out:
# Config:
#  {
#     "num_alternatives": 40,
#     "rho": 0.5,
#     "num_full_train": 5,
#     "iterations": 100,
#     "fit_frequency": 5,
#     "fit_tries": 1
# }
# Read 29 output files.

# %% [markdown]
# Let's also take a closer look by plotting replication by replication.
#
# KG first.

# %%
all_results = plot_experiment("config_1", [0,])
# Out:
# Config:
#  {
#     "num_alternatives": 5,
#     "rho": 0.5,
#     "num_full_train": 3,
#     "iterations": 200,
#     "fit_frequency": 5,
#     "fit_tries": 1
# }
# Read 50 output files.

# %%
# plot 0th setting
fig = plt.figure(figsize=(12, 8))
fig.patch.set_facecolor('xkcd:mint green')

for i in range(all_results.shape[1]):
    plt.plot(all_results[0, i])
plt.show()

# %%
means = all_results.mean(dim=1)
stds = all_results.std(dim=1)

# %%
# plot 0th setting
fig = plt.figure(figsize=(12, 8))
fig.patch.set_facecolor('xkcd:mint green')

plt.errorbar(torch.arange(200), means[0], stds[0])
plt.show()

# %% [markdown]
# TS for comparison

# %%
# plot 1st setting
fig = plt.figure(figsize=(12, 8))
fig.patch.set_facecolor('xkcd:mint green')

for i in range(all_results.shape[1]):
    plt.plot(all_results[1, i])
plt.show()

# plot 1st setting
fig = plt.figure(figsize=(12, 8))
fig.patch.set_facecolor('xkcd:mint green')

plt.errorbar(torch.arange(200), means[1], stds[1])
plt.show()

# %% [markdown]
# Let's check the averages of means and standard deviations across all iterations.

# %%
print(f"Average means: {means.mean(dim=-1)}")
print(f"Average stds: {stds.mean(dim=-1)}")
# Out:
# Average means: tensor([0.9251, 0.9072, 0.8981])
# Average stds: tensor([0.1420, 0.1760, 0.1683])

# %% [markdown]
# Let's do the same with 3rd configuration.

# %%
all_results = plot_experiment("config_3", [0,])
# Out:
# Config:
#  {
#     "num_alternatives": 20,
#     "rho": 0.7,
#     "num_full_train": 5,
#     "iterations": 100,
#     "fit_frequency": 5,
#     "fit_tries": 1
# }
# Read 49 output files.

# %%
# plot 0th setting
fig = plt.figure(figsize=(12, 8))
fig.patch.set_facecolor('xkcd:mint green')

for i in range(all_results.shape[1]):
    plt.plot(all_results[0, i])
plt.show()

# %%
means = all_results.mean(dim=1)
stds = all_results.std(dim=1)

# %%
# plot 0th setting
fig = plt.figure(figsize=(12, 8))
fig.patch.set_facecolor('xkcd:mint green')

plt.errorbar(torch.arange(100), means[0], stds[0])
plt.show()

# %% [markdown]
# PCS for comparison

# %%
# plot 2nd setting
fig = plt.figure(figsize=(12, 8))
fig.patch.set_facecolor('xkcd:mint green')

for i in range(all_results.shape[1]):
    plt.plot(all_results[2, i])
plt.show()

# plot 1st setting
fig = plt.figure(figsize=(12, 8))
fig.patch.set_facecolor('xkcd:mint green')

plt.errorbar(torch.arange(100), means[2], stds[2])
plt.show()

# %% [markdown]
# Let's check the averages of means and standard deviations across all iterations.

# %%
print(f"Average means: {means.mean(dim=-1)}")
print(f"Average stds: {stds.mean(dim=-1)}")
# Out:
# Average means: tensor([0.8475, 0.8539, 0.8202])
# Average stds: tensor([0.1566, 0.1702, 0.1952])
